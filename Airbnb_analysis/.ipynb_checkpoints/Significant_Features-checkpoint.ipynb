# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# os.chdir('C:/Users/siava/OneDrive - University of Calgary/Udacity/Project_01/Airbnb_Final_Analysis')
# os. getcwd()

# %%
city_names = ['Montreal', 'New_Brunswick', 'Quebec_City', 'Toronto', 'Vancouver', 'Victoria']

# %%
def load_features(city):
    # opening the file in read mode
    feat_file = open(f'{city}_feat.txt', 'r')
    # reading the file
    features = feat_file.read()
    # splitting the text
    feature_list = features.split("\n")
    feat_file.close()
    return feature_list[0:-1]

def all_elements(list1, list2):
    return sorted(list(set(list1 + list2)))

all_features = load_features(city_names[0])
for city in city_names[1:]:
    all_features = all_elements(load_features(city), all_features)


df_feat=pd.DataFrame(index=all_features)
for city in city_names:
    df_feat[city] = pd.DataFrame(data=True, index=load_features(city), columns=[city])


# defining a new column: sum
# shows the total number of times a feature is statistically significant amoung cities
df_feat['sum'] = df_feat.sum(axis=1, skipna=True)
df_feat.sort_values(by='sum', ascending=False, inplace=True)

df_feat.style.highlight_between(subset=['sum'], left=4, right=6, color='green')\
                    .highlight_between(subset=['sum'], left=0, right=3, color='red')\
                    .highlight_between(subset=city_names, left=False, right=True, color='lightgreen')\
                    .highlight_null(null_color='pink')
# Out:
# <style type="text/css">
# #T_46ad7_row0_col0, #T_46ad7_row0_col1, #T_46ad7_row0_col2, #T_46ad7_row0_col3, #T_46ad7_row0_col4, #T_46ad7_row0_col5, #T_46ad7_row1_col0, #T_46ad7_row1_col1, #T_46ad7_row1_col2, #T_46ad7_row1_col3, #T_46ad7_row1_col4, #T_46ad7_row1_col5, #T_46ad7_row2_col0, #T_46ad7_row2_col1, #T_46ad7_row2_col2, #T_46ad7_row2_col3, #T_46ad7_row2_col4, #T_46ad7_row2_col5, #T_46ad7_row3_col0, #T_46ad7_row3_col1, #T_46ad7_row3_col3, #T_46ad7_row3_col4, #T_46ad7_row3_col5, #T_46ad7_row4_col0, #T_46ad7_row4_col2, #T_46ad7_row4_col3, #T_46ad7_row4_col4, #T_46ad7_row4_col5, #T_46ad7_row5_col0, #T_46ad7_row5_col1, #T_46ad7_row5_col3, #T_46ad7_row5_col4, #T_46ad7_row5_col5, #T_46ad7_row6_col2, #T_46ad7_row6_col3, #T_46ad7_row6_col4, #T_46ad7_row6_col5, #T_46ad7_row7_col1, #T_46ad7_row7_col2, #T_46ad7_row7_col3, #T_46ad7_row7_col5, #T_46ad7_row8_col0, #T_46ad7_row8_col1, #T_46ad7_row8_col2, #T_46ad7_row8_col3, #T_46ad7_row9_col0, #T_46ad7_row9_col3, #T_46ad7_row9_col4, #T_46ad7_row9_col5, #T_46ad7_row10_col0, #T_46ad7_row10_col3, #T_46ad7_row10_col4, #T_46ad7_row11_col0, #T_46ad7_row11_col1, #T_46ad7_row11_col2, #T_46ad7_row12_col0, #T_46ad7_row12_col2, #T_46ad7_row12_col3, #T_46ad7_row13_col0, #T_46ad7_row13_col4, #T_46ad7_row13_col5, #T_46ad7_row14_col0, #T_46ad7_row14_col3, #T_46ad7_row14_col5, #T_46ad7_row15_col0, #T_46ad7_row15_col4, #T_46ad7_row16_col1, #T_46ad7_row16_col5, #T_46ad7_row17_col2, #T_46ad7_row17_col4, #T_46ad7_row18_col2, #T_46ad7_row18_col5 {
#   background-color: lightgreen;
# }
# #T_46ad7_row0_col6, #T_46ad7_row1_col6, #T_46ad7_row2_col6, #T_46ad7_row3_col6, #T_46ad7_row4_col6, #T_46ad7_row5_col6, #T_46ad7_row6_col6, #T_46ad7_row7_col6, #T_46ad7_row8_col6, #T_46ad7_row9_col6 {
#   background-color: green;
# }
# #T_46ad7_row3_col2, #T_46ad7_row4_col1, #T_46ad7_row5_col2, #T_46ad7_row6_col0, #T_46ad7_row6_col1, #T_46ad7_row7_col0, #T_46ad7_row7_col4, #T_46ad7_row8_col4, #T_46ad7_row8_col5, #T_46ad7_row9_col1, #T_46ad7_row9_col2, #T_46ad7_row10_col1, #T_46ad7_row10_col2, #T_46ad7_row10_col5, #T_46ad7_row11_col3, #T_46ad7_row11_col4, #T_46ad7_row11_col5, #T_46ad7_row12_col1, #T_46ad7_row12_col4, #T_46ad7_row12_col5, #T_46ad7_row13_col1, #T_46ad7_row13_col2, #T_46ad7_row13_col3, #T_46ad7_row14_col1, #T_46ad7_row14_col2, #T_46ad7_row14_col4, #T_46ad7_row15_col1, #T_46ad7_row15_col2, #T_46ad7_row15_col3, #T_46ad7_row15_col5, #T_46ad7_row16_col0, #T_46ad7_row16_col2, #T_46ad7_row16_col3, #T_46ad7_row16_col4, #T_46ad7_row17_col0, #T_46ad7_row17_col1, #T_46ad7_row17_col3, #T_46ad7_row17_col5, #T_46ad7_row18_col0, #T_46ad7_row18_col1, #T_46ad7_row18_col3, #T_46ad7_row18_col4 {
#   background-color: pink;
# }
# #T_46ad7_row10_col6, #T_46ad7_row11_col6, #T_46ad7_row12_col6, #T_46ad7_row13_col6, #T_46ad7_row14_col6, #T_46ad7_row15_col6, #T_46ad7_row16_col6, #T_46ad7_row17_col6, #T_46ad7_row18_col6 {
#   background-color: red;
# }
# </style>
# <table id="T_46ad7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Montreal</th>
#       <th class="col_heading level0 col1" >New_Brunswick</th>
#       <th class="col_heading level0 col2" >Quebec_City</th>
#       <th class="col_heading level0 col3" >Toronto</th>
#       <th class="col_heading level0 col4" >Vancouver</th>
#       <th class="col_heading level0 col5" >Victoria</th>
#       <th class="col_heading level0 col6" >sum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46ad7_level0_row0" class="row_heading level0 row0" >accommodates</th>
#       <td id="T_46ad7_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_46ad7_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_46ad7_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_46ad7_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_46ad7_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_46ad7_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_46ad7_row0_col6" class="data row0 col6" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46ad7_level0_row1" class="row_heading level0 row1" >bath_is_shared</th>
#       <td id="T_46ad7_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_46ad7_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_46ad7_row1_col2" class="data row1 col2" >True</td>
#       <td id="T_46ad7_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_46ad7_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_46ad7_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_46ad7_row1_col6" class="data row1 col6" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46ad7_level0_row2" class="row_heading level0 row2" >bathroom_numbers</th>
#       <td id="T_46ad7_row2_col0" class="data row2 col0" >True</td>
#       <td id="T_46ad7_row2_col1" class="data row2 col1" >True</td>
#       <td id="T_46ad7_row2_col2" class="data row2 col2" >True</td>
#       <td id="T_46ad7_row2_col3" class="data row2 col3" >True</td>
#       <td id="T_46ad7_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_46ad7_row2_col5" class="data row2 col5" >True</td>
#       <td id="T_46ad7_row2_col6" class="data row2 col6" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46ad7_level0_row3" class="row_heading level0 row3" >availability_30</th>
#       <td id="T_46ad7_row3_col0" class="data row3 col0" >True</td>
#       <td id="T_46ad7_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_46ad7_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_46ad7_row3_col3" class="data row3 col3" >True</td>
#       <td id="T_46ad7_row3_col4" class="data row3 col4" >True</td>
#       <td id="T_46ad7_row3_col5" class="data row3 col5" >True</td>
#       <td id="T_46ad7_row3_col6" class="data row3 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46ad7_level0_row4" class="row_heading level0 row4" >bedrooms</th>
#       <td id="T_46ad7_row4_col0" class="data row4 col0" >True</td>
#       <td id="T_46ad7_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_46ad7_row4_col2" class="data row4 col2" >True</td>
#       <td id="T_46ad7_row4_col3" class="data row4 col3" >True</td>
#       <td id="T_46ad7_row4_col4" class="data row4 col4" >True</td>
#       <td id="T_46ad7_row4_col5" class="data row4 col5" >True</td>
#       <td id="T_46ad7_row4_col6" class="data row4 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46ad7_level0_row5" class="row_heading level0 row5" >room_type_pca</th>
#       <td id="T_46ad7_row5_col0" class="data row5 col0" >True</td>
#       <td id="T_46ad7_row5_col1" class="data row5 col1" >True</td>
#       <td id="T_46ad7_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_46ad7_row5_col3" class="data row5 col3" >True</td>
#       <td id="T_46ad7_row5_col4" class="data row5 col4" >True</td>
#       <td id="T_46ad7_row5_col5" class="data row5 col5" >True</td>
#       <td id="T_46ad7_row5_col6" class="data row5 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46ad7_level0_row6" class="row_heading level0 row6" >minimum_nights</th>
#       <td id="T_46ad7_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_46ad7_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_46ad7_row6_col2" class="data row6 col2" >True</td>
#       <td id="T_46ad7_row6_col3" class="data row6 col3" >True</td>
#       <td id="T_46ad7_row6_col4" class="data row6 col4" >True</td>
#       <td id="T_46ad7_row6_col5" class="data row6 col5" >True</td>
#       <td id="T_46ad7_row6_col6" class="data row6 col6" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_46ad7_level0_row7" class="row_heading level0 row7" >number_of_reviews</th>
#       <td id="T_46ad7_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_46ad7_row7_col1" class="data row7 col1" >True</td>
#       <td id="T_46ad7_row7_col2" class="data row7 col2" >True</td>
#       <td id="T_46ad7_row7_col3" class="data row7 col3" >True</td>
#       <td id="T_46ad7_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_46ad7_row7_col5" class="data row7 col5" >True</td>
#       <td id="T_46ad7_row7_col6" class="data row7 col6"

# %%
df_feat.fillna(False, inplace=True)
df_feat.drop(columns='sum', inplace=True)
corr = df_feat.corr()

# Fill diagonal and upper half with NaNs
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
 .set_precision(2))
# Out:
# C:\Users\siava\AppData\Local\Temp/ipykernel_6304/320089868.py:9: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   (corr
# <style type="text/css">
# #T_a8123_row0_col0, #T_a8123_row0_col1, #T_a8123_row0_col2, #T_a8123_row0_col3, #T_a8123_row0_col4, #T_a8123_row0_col5, #T_a8123_row1_col1, #T_a8123_row1_col2, #T_a8123_row1_col3, #T_a8123_row1_col4, #T_a8123_row1_col5, #T_a8123_row2_col2, #T_a8123_row2_col3, #T_a8123_row2_col4, #T_a8123_row2_col5, #T_a8123_row3_col3, #T_a8123_row3_col4, #T_a8123_row3_col5, #T_a8123_row4_col4, #T_a8123_row4_col5, #T_a8123_row5_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_a8123_row1_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_a8123_row2_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_a8123_row2_col1 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_a8123_row3_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_a8123_row3_col1, #T_a8123_row5_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_a8123_row3_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_a8123_row4_col0 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_a8123_row4_col1, #T_a8123_row5_col0 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_a8123_row4_col2 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_a8123_row4_col3, #T_a8123_row5_col4 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_a8123_row5_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_a8123_row5_col3 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# </style>
# <table id="T_a8123_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Montreal</th>
#       <th class="col_heading level0 col1" >New_Brunswick</th>
#       <th class="col_heading level0 col2" >Quebec_City</th>
#       <th class="col_heading level0 col3" >Toronto</th>
#       <th class="col_heading level0 col4" >Vancouver</th>
#       <th class="col_heading level0 col5" >Victoria</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8123_level0_row0" class="row_heading level0 row0" >Montreal</th>
#       <td id="T_a8123_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_a8123_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_a8123_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_a8123_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_a8123_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_a8123_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a8123_level0_row1" class="row_heading level0 row1" >New_Brunswick</th>
#       <td id="T_a8123_row1_col0" class="data row1 col0" >0.09</td>
#       <td id="T_a8123_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_a8123_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_a8123_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_a8123_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_a8123_row1_col5" class="data row1 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a8123_level0_row2" class="row_heading level0 row2" >Quebec_City</th>
#       <td id="T_a8123_row2_col0" class="data row2 col0" >-0.27</td>
#       <td id="T_a8123_row2_col1" class="data row2 col1" >0.17</td>
#       <td id="T_a8123_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_a8123_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_a8123_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_a8123_row2_col5" class="data row2 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a8123_level0_row3" class="row_heading level0 row3" >Toronto</th>
#       <td id="T_a8123_row3_col0" class="data row3 col0" >0.37</td>
#       <td id="T_a8123_row3_col1" class="data row3 col1" >0.19</td>
#       <td id="T_a8123_row3_col2" class="data row3 col2" >0.11</td>
#       <td id="T_a8123_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_a8123_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_a8123_row3_col5" class="data row3 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a8123_level0_row4" class="row_heading level0 row4" >Vancouver</th>
#       <td id="T_a8123_row4_col0" class="data row4 col0" >0.29</td>
#       <td id="T_a8123_row4_col1" class="data row4 col1" >-0.15</td>
#       <td id="T_a8123_row4_col2" class="data row4 col2" >-0.21</td>
#       <td id="T_a8123_row4_col3" class="data row4 col3" >0.19</td>
#       <td id="T_a8123_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_a8123_row4_col5" class="data row4 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a8123_level0_row5" class="row_heading level0 row5" >Victoria</th>
#       <td id="T_a8123_row5_col0" class="data row5 col0" >-0.15</td>
#       <td id="T_a8123_row5_col1" class="data row5 col1" >0.19</td>
#       <td id="T_a8123_row5_col2" class="data row5 col2" >-0.12</td>
#       <td id="T_a8123_row5_col3" class="data row5 col3" >0.27</td>
#       <td id="T_a8123_row5_col4" class="data row5 col4" >0.19</td>
#       <td id="T_a8123_row5_col5" class="data row5 col5" >nan</td>
#     </tr>
#   </tbody>
# </table>
