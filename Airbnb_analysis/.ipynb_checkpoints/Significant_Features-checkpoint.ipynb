# %% [markdown]
# # Comparing Significant Features for Different Cities

# %% [markdown]
# ## Summary
# <br> The list of significant features for predicting the Airbnb price of a listing was analysed and exported in a txt file for each city.
# <br> Here, the lists are loaded and compared to specify a general guidline for important listing features

# %% [markdown]
# <br> loading necessary libraries

# %%
# import os
import pandas as pd
import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <br> list of cities

# %%
city_names = ['Montreal', 'New_Brunswick', 'Quebec_City', 'Toronto', 'Vancouver', 'Victoria']

# %% [markdown]
# <br> loading features and creating a data frame to compare the cities

# %%
def load_features(city):
    # opening the file in read mode
    feat_file = open(f'{city}_feat.txt', 'r')
    # reading the file
    features = feat_file.read()
    # splitting the text
    feature_list = features.split("\n")
    feat_file.close()
    return feature_list[0:-1]

def all_elements(list1, list2):
    return sorted(list(set(list1 + list2)))

all_features = load_features(city_names[0])
for city in city_names[1:]:
    all_features = all_elements(load_features(city), all_features)

df_feat=pd.DataFrame(index=all_features)
for city in city_names:
    df_feat[city] = pd.DataFrame(data=True, index=load_features(city), columns=[city])


# defining a new column: sum
# shows the total number of times a feature is statistically significant amoung cities
df_feat['sum'] = df_feat.sum(axis=1, skipna=True)
df_feat.sort_values(by='sum', ascending=False, inplace=True)

df_feat.style.highlight_between(subset=['sum'], left=4, right=6, color='green')\
                    .highlight_between(subset=['sum'], left=0, right=3, color='red')\
                    .highlight_between(subset=city_names, left=False, right=True, color='lightgreen')\
                    .highlight_null(null_color='pink')
# Out:
# <style type="text/css">
# #T_d9f6d_row0_col0, #T_d9f6d_row0_col1, #T_d9f6d_row0_col2, #T_d9f6d_row0_col3, #T_d9f6d_row0_col4, #T_d9f6d_row0_col5, #T_d9f6d_row1_col0, #T_d9f6d_row1_col1, #T_d9f6d_row1_col2, #T_d9f6d_row1_col3, #T_d9f6d_row1_col4, #T_d9f6d_row1_col5, #T_d9f6d_row2_col0, #T_d9f6d_row2_col1, #T_d9f6d_row2_col2, #T_d9f6d_row2_col3, #T_d9f6d_row2_col4, #T_d9f6d_row2_col5, #T_d9f6d_row3_col0, #T_d9f6d_row3_col1, #T_d9f6d_row3_col3, #T_d9f6d_row3_col4, #T_d9f6d_row3_col5, #T_d9f6d_row4_col0, #T_d9f6d_row4_col2, #T_d9f6d_row4_col3, #T_d9f6d_row4_col4, #T_d9f6d_row4_col5, #T_d9f6d_row5_col0, #T_d9f6d_row5_col1, #T_d9f6d_row5_col3, #T_d9f6d_row5_col4, #T_d9f6d_row5_col5, #T_d9f6d_row6_col2, #T_d9f6d_row6_col3, #T_d9f6d_row6_col4, #T_d9f6d_row6_col5, #T_d9f6d_row7_col1, #T_d9f6d_row7_col2, #T_d9f6d_row7_col3, #T_d9f6d_row7_col5, #T_d9f6d_row8_col0, #T_d9f6d_row8_col1, #T_d9f6d_row8_col2, #T_d9f6d_row8_col3, #T_d9f6d_row9_col0, #T_d9f6d_row9_col3, #T_d9f6d_row9_col4, #T_d9f6d_row9_col5, #T_d9f6d_row10_col0, #T_d9f6d_row10_col3, #T_d9f6d_row10_col4, #T_d9f6d_row11_col0, #T_d9f6d_row11_col1, #T_d9f6d_row11_col2, #T_d9f6d_row12_col0, #T_d9f6d_row12_col2, #T_d9f6d_row12_col3, #T_d9f6d_row13_col0, #T_d9f6d_row13_col4, #T_d9f6d_row13_col5, #T_d9f6d_row14_col0, #T_d9f6d_row14_col3, #T_d9f6d_row14_col5, #T_d9f6d_row15_col0, #T_d9f6d_row15_col4, #T_d9f6d_row16_col1, #T_d9f6d_row16_col5, #T_d9f6d_row17_col2, #T_d9f6d_row17_col4, #T_d9f6d_row18_col2, #T_d9f6d_row18_col5 {
#   background-color: lightgreen;
# }
# #T_d9f6d_row0_col6, #T_d9f6d_row1_col6, #T_d9f6d_row2_col6, #T_d9f6d_row3_col6, #T_d9f6d_row4_col6, #T_d9f6d_row5_col6, #T_d9f6d_row6_col6, #T_d9f6d_row7_col6, #T_d9f6d_row8_col6, #T_d9f6d_row9_col6 {
#   background-color: green;
# }
# #T_d9f6d_row3_col2, #T_d9f6d_row4_col1, #T_d9f6d_row5_col2, #T_d9f6d_row6_col0, #T_d9f6d_row6_col1, #T_d9f6d_row7_col0, #T_d9f6d_row7_col4, #T_d9f6d_row8_col4, #T_d9f6d_row8_col5, #T_d9f6d_row9_col1, #T_d9f6d_row9_col2, #T_d9f6d_row10_col1, #T_d9f6d_row10_col2, #T_d9f6d_row10_col5, #T_d9f6d_row11_col3, #T_d9f6d_row11_col4, #T_d9f6d_row11_col5, #T_d9f6d_row12_col1, #T_d9f6d_row12_col4, #T_d9f6d_row12_col5, #T_d9f6d_row13_col1, #T_d9f6d_row13_col2, #T_d9f6d_row13_col3, #T_d9f6d_row14_col1, #T_d9f6d_row14_col2, #T_d9f6d_row14_col4, #T_d9f6d_row15_col1, #T_d9f6d_row15_col2, #T_d9f6d_row15_col3, #T_d9f6d_row15_col5, #T_d9f6d_row16_col0, #T_d9f6d_row16_col2, #T_d9f6d_row16_col3, #T_d9f6d_row16_col4, #T_d9f6d_row17_col0, #T_d9f6d_row17_col1, #T_d9f6d_row17_col3, #T_d9f6d_row17_col5, #T_d9f6d_row18_col0, #T_d9f6d_row18_col1, #T_d9f6d_row18_col3, #T_d9f6d_row18_col4 {
#   background-color: pink;
# }
# #T_d9f6d_row10_col6, #T_d9f6d_row11_col6, #T_d9f6d_row12_col6, #T_d9f6d_row13_col6, #T_d9f6d_row14_col6, #T_d9f6d_row15_col6, #T_d9f6d_row16_col6, #T_d9f6d_row17_col6, #T_d9f6d_row18_col6 {
#   background-color: red;
# }
# </style>
# <table id="T_d9f6d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Montreal</th>
#       <th class="col_heading level0 col1" >New_Brunswick</th>
#       <th class="col_heading level0 col2" >Quebec_City</th>
#       <th class="col_heading level0 col3" >Toronto</th>
#       <th class="col_heading level0 col4" >Vancouver</th>
#       <th class="col_heading level0 col5" >Victoria</th>
#       <th class="col_heading level0 col6" >sum</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9f6d_level0_row0" class="row_heading level0 row0" >accommodates</th>
#       <td id="T_d9f6d_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_d9f6d_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_d9f6d_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_d9f6d_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_d9f6d_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_d9f6d_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_d9f6d_row0_col6" class="data row0 col6" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9f6d_level0_row1" class="row_heading level0 row1" >bath_is_shared</th>
#       <td id="T_d9f6d_row1_col0" class="data row1 col0" >True</td>
#       <td id="T_d9f6d_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_d9f6d_row1_col2" class="data row1 col2" >True</td>
#       <td id="T_d9f6d_row1_col3" class="data row1 col3" >True</td>
#       <td id="T_d9f6d_row1_col4" class="data row1 col4" >True</td>
#       <td id="T_d9f6d_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_d9f6d_row1_col6" class="data row1 col6" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9f6d_level0_row2" class="row_heading level0 row2" >bathroom_numbers</th>
#       <td id="T_d9f6d_row2_col0" class="data row2 col0" >True</td>
#       <td id="T_d9f6d_row2_col1" class="data row2 col1" >True</td>
#       <td id="T_d9f6d_row2_col2" class="data row2 col2" >True</td>
#       <td id="T_d9f6d_row2_col3" class="data row2 col3" >True</td>
#       <td id="T_d9f6d_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_d9f6d_row2_col5" class="data row2 col5" >True</td>
#       <td id="T_d9f6d_row2_col6" class="data row2 col6" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9f6d_level0_row3" class="row_heading level0 row3" >availability_30</th>
#       <td id="T_d9f6d_row3_col0" class="data row3 col0" >True</td>
#       <td id="T_d9f6d_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_d9f6d_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_d9f6d_row3_col3" class="data row3 col3" >True</td>
#       <td id="T_d9f6d_row3_col4" class="data row3 col4" >True</td>
#       <td id="T_d9f6d_row3_col5" class="data row3 col5" >True</td>
#       <td id="T_d9f6d_row3_col6" class="data row3 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9f6d_level0_row4" class="row_heading level0 row4" >bedrooms</th>
#       <td id="T_d9f6d_row4_col0" class="data row4 col0" >True</td>
#       <td id="T_d9f6d_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_d9f6d_row4_col2" class="data row4 col2" >True</td>
#       <td id="T_d9f6d_row4_col3" class="data row4 col3" >True</td>
#       <td id="T_d9f6d_row4_col4" class="data row4 col4" >True</td>
#       <td id="T_d9f6d_row4_col5" class="data row4 col5" >True</td>
#       <td id="T_d9f6d_row4_col6" class="data row4 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9f6d_level0_row5" class="row_heading level0 row5" >room_type_pca</th>
#       <td id="T_d9f6d_row5_col0" class="data row5 col0" >True</td>
#       <td id="T_d9f6d_row5_col1" class="data row5 col1" >True</td>
#       <td id="T_d9f6d_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_d9f6d_row5_col3" class="data row5 col3" >True</td>
#       <td id="T_d9f6d_row5_col4" class="data row5 col4" >True</td>
#       <td id="T_d9f6d_row5_col5" class="data row5 col5" >True</td>
#       <td id="T_d9f6d_row5_col6" class="data row5 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9f6d_level0_row6" class="row_heading level0 row6" >minimum_nights</th>
#       <td id="T_d9f6d_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_d9f6d_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_d9f6d_row6_col2" class="data row6 col2" >True</td>
#       <td id="T_d9f6d_row6_col3" class="data row6 col3" >True</td>
#       <td id="T_d9f6d_row6_col4" class="data row6 col4" >True</td>
#       <td id="T_d9f6d_row6_col5" class="data row6 col5" >True</td>
#       <td id="T_d9f6d_row6_col6" class="data row6 col6" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d9f6d_level0_row7" class="row_heading level0 row7" >number_of_reviews</th>
#       <td id="T_d9f6d_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_d9f6d_row7_col1" class="data row7 col1" >True</td>
#       <td id="T_d9f6d_row7_col2" class="data row7 col2" >True</td>
#       <td id="T_d9f6d_row7_col3" class="data row7 col3" >True</td>
#       <td id="T_d9f6d_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_d9f6d_row7_col5" class="data row7 col5" >True</td>
#       <td id="T_d9f6d_row7_col6" class="data row7 col6"
